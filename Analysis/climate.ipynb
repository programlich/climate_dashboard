# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Global Temperature
# ### Reconstructed from year 1 - 2000

# %%
temp_early = pd.read_csv("../Daten/SPM1_1-2000.csv")
temp_early
# Out:
#       year  temp    5%   95%
# 0     1995  0.65  0.46  0.79
# 1     1994  0.64  0.46  0.77
# 2     1993  0.62  0.45  0.76
# 3     1992  0.61  0.45  0.74
# 4     1991  0.59  0.44  0.71
# ...    ...   ...   ...   ...
# 1986     9  0.10 -0.11  0.38
# 1987     8  0.10 -0.11  0.38
# 1988     7  0.09 -0.11  0.38
# 1989     6  0.09 -0.12  0.37
# 1990     5  0.08 -0.13  0.37
#
# [1991 rows x 4 columns]

# %%
plt.style.use('default')
#sns.set_theme()
plt.plot(temp_early["year"], temp_early["temp"])
plt.xlabel("Jahr")
plt.ylabel("Temperaturänderung / °C")
plt.title("Änderung der Oberflächentemperatur bezogen auf den Jahrzehntedurchschnitt (rekonstruiert)")
# Out:
# Text(0.5, 1.0, 'Änderung der Oberflächentemperatur bezogen auf den Jahrzehntedurchschnitt (rekonstruiert)')

# %% [markdown]
# ## Gemessene Temperaturänderung seit 1850

# %%
colnames = ["year", "human_natural", "human_natural_top", "human_natural_bottom", "natural", "natural_top", "natural_bottom", "observerd" ]
temp_recent = pd.read_csv("../Daten/gmst_changes_model_and_obs.csv", skiprows=36, skipfooter=1, names=colnames, header=None, engine="python")
temp_recent
# Out:
#      year  human_natural  human_natural_top  human_natural_bottom   natural  \
# 0    1850      -0.047589          -0.354805              0.189713  0.014602
# 1    1851      -0.058761          -0.313445              0.149283  0.024195
# 2    1852      -0.002935          -0.174406              0.198393  0.052558
# 3    1853      -0.005929          -0.214802              0.217604  0.029406
# 4    1854      -0.026611          -0.224447              0.221410 -0.009961
# ..    ...            ...                ...                   ...       ...
# 165  2015       1.042083           0.525009              1.743674  0.056505
# 166  2016       1.057188           0.507333              1.744812  0.048938
# 167  2017       1.100092           0.727634              1.781020  0.047106
# 168  2018       1.170450           0.806942              1.872942  0.044185
# 169  2019       1.189952           0.738261              1.870786  0.049385
#
#      natural_top  natural_bottom  observerd
# 0      -0.161195        0.196198     -0.059
# 1      -0.132961        0.179928      0.049
# 2      -0.202666        0.221706      0.079
# 3      -0.266416        0.178987      0.046
# 4      -0.255841        0.152485      0.049
# ..           ...             ...        ...
# 165    -0.216157        0.350697      1.149
# 166    -0.268107        0.290533      1.264
# 167    -0.201490        0.319119      1.179
# 168    -0.222528        0.383822      1.101
# 169    -0.136320        0.306537      1.226
#
# [170 rows x 8 columns]

# %%
plt.plot(temp_recent["year"], temp_recent["observerd"])
plt.xlabel("Jahr")
plt.ylabel("Änderung der Oberflächentemperatur / °C")
# Out:
# Text(0, 0.5, 'Änderung der Oberflächentemperatur / °C')

# %% [markdown]
# # CO2 Konzentration in der Atmosphäre
# ## Gemessene Konzentration

# %%
ghg_observed = pd.read_csv("../Daten/table_A3.1_historical_abundances.csv", skiprows=37, skipfooter=1,encoding="unicode_escape", usecols=["YYYY", "CO2", "CH4", "N2O"], engine="python")
ghg_observed.rename(columns={"YYYY":"year","CO2":"co2","CH4":"ch4","N2O":"n2o"}, inplace=True)
ghg_observed
# Out:
#      year    co2     ch4    n2o
# 0    1750  278.3   729.2  270.1
# 1    1850  285.5   807.6  272.1
# 2    1851  285.6   807.8  272.2
# 3    1852  285.8   808.5  272.3
# 4    1853  285.9   809.8  272.4
# ..    ...    ...     ...    ...
# 166  2015  399.4  1834.0  328.3
# 167  2016  402.9  1842.2  329.1
# 168  2017  405.0  1849.2  330.0
# 169  2018  407.4  1857.8  331.2
# 170  2019  409.9  1866.3  332.1
#
# [171 rows x 4 columns]

# %%
plt.plot(ghg_observed["year"], ghg_observed["co2"])
plt.xlabel("Jahr")
plt.ylabel("CO2-Konzentration / ppm")
# Out:
# Text(0, 0.5, 'CO2-Konzentration / ppm')

# %% [markdown]
# ## Prognostizierte Verläufe der CO2 Konzetration je nach Szenario

# %%
co2_projections = pd.read_excel("../Daten/IPCC_AR6_AnnexIII_Tab2_future_co2_concentration.xlsx")
co2_projections
# Out:
#    year  co2_ssp119  co2_ssp126  co2_ssp245  co2_ssp370  co2_ssp585
# 0  2020         414         414         414         415         415
# 1  2030         434         440         444         451         452
# 2  2040         440         458         475         493         500
# 3  2050         438         469         507         541         563
# 4  2060         431         474         537         593         643
# 5  2070         424         473         564         652         744
# 6  2080         415         467         585         716         864
# 7  2090         405         457         598         787         998
# 8  2100         394         446         603         867        1135

# %%
co2_projections_ssps = ['co2_ssp119', 'co2_ssp126', 'co2_ssp245', 'co2_ssp370',
       'co2_ssp585']
for ssp in co2_projections_ssps:
    plt.plot(co2_projections["year"],co2_projections[ssp], label = ssp)

plt.xlabel("Jahr")
plt.ylabel("Co2-Konzentration / ppm")
plt.legend()

# %%
co2_projections_ssps = ['co2_ssp119', 'co2_ssp126', 'co2_ssp245', 'co2_ssp370',
       'co2_ssp585']
for ssp in co2_projections_ssps:
    plt.plot(co2_projections["year"],co2_projections[ssp], label = ssp)

plt.xlabel("Jahr")
plt.ylabel("Co2-Konzentration / ppm")
plt.plot(ghg_observed["year"],ghg_observed["co2"], label = "co2_gemessen")
plt.legend()

# %% [markdown]
# # CO2 emissions per country

# %%
emissions = pd.read_excel("../Daten/EDGARv7.0_FT2021_fossil_CO2_booklet_2022.xlsx", sheet_name="fossil_CO2_totals_by_country").dropna()
emissions
# Out:
#     Substance EDGAR Country Code                 Country          1970  \
# 0         CO2                ABW                   Aruba      0.081876
# 1         CO2                AFG             Afghanistan      1.739541
# 2         CO2                AGO                  Angola      8.952570
# 3         CO2                AIA                Anguilla      0.002168
# 4         CO2                AIR  International Aviation    169.300997
# ..        ...                ...                     ...           ...
# 207       CO2                ZAF            South Africa    185.640021
# 208       CO2                ZMB                  Zambia      3.670158
# 209       CO2                ZWE                Zimbabwe      9.669320
# 211       CO2               EU27                    EU27   3542.825533
# 212       CO2       GLOBAL TOTAL            GLOBAL TOTAL  16120.846944
#
#              1971          1972          1973          1974          1975  \
# 0        0.081889      0.095415      0.099630      0.089089      0.105139
# 1        1.737823      1.715749      1.742813      2.198551      2.037627
# 2        8.538308     10.388519     11.372301     11.833761     10.930423
# 3        0.002168      0.002264      0.002109      0.002350      0.002584
# 4      169.300997    179.147487    186.892096    179.793331    173.866020
# ..            ...           ...           ...           ...           ...
# 207    184.557782    191.212162    208.378907    215.229511    231.208302
# 208      3.827327      4.235602      4.549516      4.584571      4.756705
# 209      9.616592      9.164476     10.612888     10.303574      9.088979
# 211   3553.664800   3697.504907   3887.115359   3833.301897   3744.235427
# 212  16044.985082  16846.420428  17841.770662  17788.085297  17726.890288
#
#              1976  ...          2012          2013          2014  \
# 0        0.096041  ...      1.618441      1.588689      1.615728
# 1        1.899895  ...     10.238064      8.484183      8.016290
# 2        7.317385  ...     24.186843     27.822325     30.407844
# 3        0.002434  ...      0.026023      0.027941      0.027896
# 4      174.273791  ...    472.721119    480.909126    496.627697
# ..            ...  ...           ...           ...           ...
# 207    245.600945  ...    459.783780    471.432912    482.539654
# 208      4.757159  ...      4.353041      4.560796      4.995499
# 209     10.059936  ...     12.458577     12.756765     12.647276
# 211   3996.612030  ...   3262.094670   3182.700438   3039.771438
# 212  18731.800773  ...  35702.300084  36188.848770  36412.197346
#
#              2015          2016          2017          2018          2019  \
# 0        1.607879      1.578644      1.315458      1.347594      1.387156
# 1        8.361849      7.635914      8.145255      9.106997      8.082724
# 2       32.594130     30.691660     26.129882     24.048619     25.325994
# 3        0.028005      0.028340      0.029062      0.028223      0.027580
# 4      524.654035    548.207777    582.230490    609.630469    617.763229
# ..            ...           ...           ...           ...           ...
# 207    458.824044    458.689488    468.790178    467.184261    470.522116
# 208      5.314527      5.783061      7.265927      8.268376      7.084711
# 209     12.875895     11.312592     10.540316     12.730372     12.088218
# 211   3097.973498   3106.408744   3130.214112   3065.688131   2922.049472
# 212  36301.976569  36392.322786  37014.179184  37876.882570  37993.282002
#
#              2020          2021
# 0        1.144333      1.274134
# 1        8.183718      8.347669
# 2       23.055844     24.450057
# 3        0.022779      0.025409
# 4      338.144083    390.166250
# ..            ...           ...
# 207    427.815947    435.522812
# 208      6.618359      7.010965
# 209     11.443394     12.293227
# 211   2605.119130   2774.926525
# 212  35960.674107  37857.575755
#
# [212 rows x 55 columns]

# %%
# Create a df with all the global co2 emissions per year 
global_total = emissions.loc[emissions["Country"]=="GLOBAL TOTAL",1970:].melt(var_name="year",value_name="total_emissions")
global_total["total_emissions"] = global_total["total_emissions"]/1000 #Convert unit from Mt to Gt

# Define a function to get the global co2 emissions of a certain year
def year_global_total_emissions(year):
    return global_total.loc[global_total["year"]==year,"total_emissions"].values[0]

# Plot the global total co2 emissions over time
plt.plot(global_total["year"], global_total["total_emissions"])
plt.xlabel("Jahr")
plt.ylabel("Globalee CO2 Emissionen / Gt")
# Out:
# Text(0, 0.5, 'Globalee CO2 Emissionen / Gt')

# %% [markdown]
# ## CO2 emissions per country per capita

# %%
emissions_capita = pd.read_excel("../Daten/EDGARv7.0_FT2021_fossil_CO2_booklet_2022.xlsx",
                                 sheet_name="fossil_CO2_per_capita_by_countr",skipfooter=3).dropna()
emissions_capita
# Out:
#     Substance EDGAR Country Code       Country      1970      1971      1972  \
# 0         CO2                ABW         Aruba  1.386249  1.377678  1.594510
# 1         CO2                AFG   Afghanistan  0.156348  0.152203  0.146371
# 2         CO2                AGO        Angola  1.321143  1.232565  1.464238
# 3         CO2                AIA      Anguilla  0.338637  0.336122  0.348216
# 5         CO2                ALB       Albania  2.238685  2.186541  2.439749
# ..        ...                ...           ...       ...       ...       ...
# 205       CO2                WSM         Samoa  0.464206  0.457079  0.480896
# 206       CO2                YEM         Yemen  0.262898  0.260527  0.300571
# 207       CO2                ZAF  South Africa  8.128025  7.859275  7.918311
# 208       CO2                ZMB        Zambia  0.879290  0.886366  0.947562
# 209       CO2                ZWE      Zimbabwe  1.868244  1.797094  1.655472
#
#          1973      1974      1975      1976  ...       2012       2013  \
# 0    1.653806  1.471866  1.733329  1.585203  ...  15.777813  15.396213
# 1    0.144899  0.178432  0.161841  0.147963  ...   0.333520   0.267372
# 2    1.562567  1.583252  1.422773  0.926134  ...   0.963765   1.070159
# 3    0.321684  0.356316  0.389807  0.365537  ...   1.841831   1.954019
# 5    2.142181  2.255601  2.245509  2.347782  ...   1.566529   1.648297
# ..        ...       ...       ...       ...  ...        ...        ...
# 205  0.571587  0.694310  0.569824  0.557814  ...   1.453471   1.414304
# 206  0.359195  0.350062  0.327051  0.388369  ...   0.882681   1.124740
# 207  8.392325  8.433890  8.820570  9.128687  ...   8.675460   8.768006
# 208  0.982617  0.956115  0.958240  0.925697  ...   0.296125   0.300983
# 209  1.853119  1.740192  1.486252  1.594714  ...   0.846900   0.847372
#
#           2014       2015       2016       2017       2018       2019  \
# 0    15.566530  15.409848  15.060231  12.496750  12.752857  13.079835
# 1     0.244712   0.247858   0.220335   0.229249   0.250377   0.217225
# 2     1.129542   1.169955   1.065183   0.877307   0.781454   0.796726
# 3     1.929322   1.916736   1.919526   1.949322   1.875905   1.817582
# 5     1.757988   1.681673   1.578590   1.824771   1.811292   1.714733
# ..         ...        ...        ...        ...        ...        ...
# 205   1.407321   1.604945   1.658657   1.620609   1.565223   1.737568
# 206   1.079720   0.529336   0.403081   0.378612   0.360282   0.416091
# 207   8.847510   8.298320   8.188617   8.265397   8.139323   8.103355
# 208   0.319794   0.330095   0.348566   0.425057   0.469527   0.390622
# 209   0.820628   0.816092   0.700453   0.637652   0.752686   0.698842
#
#           2020       2021
# 0    10.751174  11.907793
# 1     0.215050   0.214516
# 2     0.702335   0.721368
# 3     1.490512   1.693915
# 5     1.599886   1.559482
# ..         ...        ...
# 205   1.735972   1.783315
# 206   0.383794   0.389740
# 207   7.285541   7.336233
# 208   0.354321   0.364490
# 209   0.647234   0.680688
#
# [208 rows x 55 columns]

# %%
# Function that plots the per capita emissions of a list of countries in a specified year
def plot_country_capita_emissions(countries, year):
    if type(countries) != list:
        return
    for country in countries:
        plt.bar(x=country,height=emissions_capita.loc[emissions_capita["Country"] == country,year], label=country)
    plt.legend()
    year_average = emissions_capita[year].mean()
    plt.axhline(year_average,color="black")
plot_country_capita_emissions(["Germany", "United States", "Peru", "China", "Russia"],2020)

# %% [markdown]
# # CO2-Budget
# In this part the remaining CO2-budget will be calculated which still can be emitted before breaking the 1,5°C limit. In the AR6 of IPCC in table SPM.2 the remaining CO2 budget from january 2020 is calculated as 400 Gt CO2 to reach to 1,5° goal with a 67% probability.
# From these 400 Gt the observed global emissions as reported in EDGAR7.0 will be substracted. To calculate the emissions of the time difference between 2021 and now the average global emissions between 2015 and 2021 will be used. Linear emission over time is assumed.

# %%
import datetime as dt 

# Calculate the average global co2 emissions between 2015 and 2021. Year 2020 will not be part of the average because the emissions 
# where quite low due to the covid pandemic
global_avg_15_21 = global_total.loc[global_total["year"].isin([2015,2016,2017,2018,2019,2021]),"total_emissions"].mean()
print("Global average co2 emissions between 2015 an 2021:",round(global_avg_15_21,3),"Gt")

# Emissions of 2020 and 2021
emissions_20_21 = (year_global_total_emissions(2020) + year_global_total_emissions(2021))
print("The total global co2 emissions of 2020 and 2021 are:",round(emissions_20_21,3),"Gt")

# Emissions since january 2022
average_global_co2_per_second = global_avg_15_21/365/24/60/60 * 1000000000  #value in t/s
print("Global average co2 emissions:",round(average_global_co2_per_second),"t/s")
time_since_jan22 = dt.datetime.now() - dt.datetime(2022,1,1)  #Time difference between jan 2020 and now
used_since_jan_22 = time_since_jan22.total_seconds() * average_global_co2_per_second  /1000000000 #Used co2 budget since jan2020 in Gt

# Remaining co2 budget
remaining = 400 - emissions_20_21 - used_since_jan_22    #Remaining co2 budget in Gt
print("Remaining CO2 budget:",round(remaining,3),"Gt")
# Out:
# Global average co2 emissions between 2015 an 2021: 37.239 Gt
# The total global co2 emissions of 2020 and 2021 are: 73.818 Gt
# Global average co2 emissions: 1181 t/s
# Remaining CO2 budget: 293.562 Gt
